# %%
import pandas as pd

# %%
df = pd.read_csv('example')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('My_output')

# %%
pd.read_csv('My_output')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
conda install xlrd
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
#
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\anaconda3
#
#   added / updated specs:
#     - xlrd
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2023.7.22          |  py311haa95532_0         155 KB
#     conda-23.7.2               |  py311haa95532_0         1.3 MB
#     jupyter_client-7.4.9       |  py311haa95532_0         278 KB
#     jupyter_server-1.23.4      |  py311haa95532_0         459 KB
#     openssl-1.1.1v             |       h2bbff1b_0         5.5 MB
#     pyzmq-23.2.0               |  py311hd77b12b_0         476 KB
#     xlrd-2.0.1                 |     pyhd3eb1b0_1          97 KB
#     ------------------------------------------------------------
#                                            Total:         8.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   xlrd               pkgs/main/noarch::xlrd-2.0.1-pyhd3eb1b0_1
#
# The following packages will be UPDATED:
#
#   certifi                          2023.5.7-py311haa95532_0 --> 2023.7.22-py311haa95532_0
#   conda                              23.5.2-py311haa95532_0 --> 23.7.2-py311haa95532_0
#   openssl                                 1.1.1u-h2bbff1b_0 --> 1.1.1v-h2bbff1b_0
#
# The following packages will be DOWNGRADED:
#
#   jupyter_client                      8.1.0-py311haa95532_0 --> 7.4.9-py311haa95532_0
#   jupyter_server                      2.5.0-py311haa95532_0 --> 1.23.4-py311haa95532_0
#   pyzmq                              25.1.0-py311hd77b12b_0 --> 23.2.0-py311hd77b12b_0
#
#
#
# Downloading and Extracting Packages
#
# jupyter_client-7.4.9 | 278 KB    |            |   0%
#
# conda-23.7.2         | 1.3 MB    |            |   0%
#
#
# xlrd-2.0.1           | 97 KB     |            |   0%
#
#
#
# openssl-1.1.1v       | 5.5 MB    |            |   0%
#
#
#
#
# pyzmq-23.2.0         | 476 KB    |            |   0%
#
#
#
#
#
# certifi-2023.7.22    | 155 KB    |            |   0%
#
#
#
#
#
#
# jupyter_server-1.23. | 459 KB    |            |   0%
#
#
#
#
# pyzmq-23.2.0         | 476 KB    | 3          |   3%
# jupyter_client-7.4.9 | 278 KB    | 5          |   6%
#
#
# xlrd-2.0.1           | 97 KB     | #6         |  17%
#
# conda-23.7.2         | 1.3 MB    | 1          |   1%
#
#
#
# openssl-1.1.1v       | 5.5 MB    |            |   0%
#
#
#
#
# pyzmq-23.2.0         | 476 KB    | ##3        |  24%
# jupyter_client-7.4.9 | 278 KB    | ##8        |  29%
#
#
# xlrd-2.0.1           | 97 KB     | ####9      |  50%
#
#
#
#
# pyzmq-23.2.0         | 476 KB    | ###3       |  34%
#
#
#
# openssl-1.1.1v       | 5.5 MB    |            |   1%
#
# conda-23.7.2         | 1.3 MB    | 3          |   4%
# jupyter_client-7.4.9 | 278 KB    | ####6      |  46%
#
# conda-23.7.2         | 1.3 MB    | 5          |   6%
# jupyter_client-7.4.9 | 278 KB    | #####7     |  58%
#
#
# xlrd-2.0.1           | 97 KB     | ########2  |  83%
#
#
# xlrd-2.0.1           | 97 KB     | ########## | 100%
#
#
# xlrd-2.0.1           | 97 KB     | ########## | 100%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | 1          |   1%
#
#
#
#
# pyzmq-23.2.0         | 476 KB    | ####3      |  44%
# jupyter_client-7.4.9 | 278 KB    | #######4   |  75%
#
#
#
#
#
# certifi-2023.7.22    | 155 KB    | #          |  10%
#
# conda-23.7.2         | 1.3 MB    | 9          |   9%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | 3          |   4%
#
#
#
#
# pyzmq-23.2.0         | 476 KB    | #######3   |  74%
#
#
#
#
#
# certifi-2023.7.22    | 155 KB    | ####1      |  41%
# jupyter_client-7.4.9 | 278 KB    | ########## | 100%
# jupyter_client-7.4.9 | 278 KB    | ########## | 100%
#
# conda-23.7.2         | 1.3 MB    | #7         |  18%
#
#
#
#
# pyzmq-23.2.0         | 476 KB    | ########7  |  87%
#
#
#
#
#
#
# jupyter_server-1.23. | 459 KB    | 3          |   3%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | 4          |   5%
#
# conda-23.7.2         | 1.3 MB    | ##         |  20%
#
#
#
#
#
# certifi-2023.7.22    | 155 KB    | ######2    |  62%
#
#
#
#
#
#
# jupyter_server-1.23. | 459 KB    | ##7        |  28%
#
# conda-23.7.2         | 1.3 MB    | ##8        |  28%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | 5          |   6%
#
#
#
#
#
# certifi-2023.7.22    | 155 KB    | ########## | 100%
#
#
#
#
#
# certifi-2023.7.22    | 155 KB    | ########## | 100%
#
#
#
#
#
#
# jupyter_server-1.23. | 459 KB    | ####5      |  45%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | 7          |   7%
#
# conda-23.7.2         | 1.3 MB    | ###3       |  33%
#
#
#
#
#
#
# jupyter_server-1.23. | 459 KB    | ######2    |  63%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | 8          |   9%
#
# conda-23.7.2         | 1.3 MB    | ###6       |  37%
#
#
#
#
# pyzmq-23.2.0         | 476 KB    | ########## | 100%
#
#
#
#
# pyzmq-23.2.0         | 476 KB    | ########## | 100%
#
#
#
#
#
#
# jupyter_server-1.23. | 459 KB    | #######6   |  77%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | 9          |   9%
#
# conda-23.7.2         | 1.3 MB    | ####       |  40%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | #          |  10%
#
#
#
#
#
#
# jupyter_server-1.23. | 459 KB    | #########  |  91%
#
# conda-23.7.2         | 1.3 MB    | ####3      |  44%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | #2         |  12%
#
# conda-23.7.2         | 1.3 MB    | #####      |  51%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | #3         |  13%
#
# conda-23.7.2         | 1.3 MB    | #####5     |  56%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | #4         |  14%
#
# conda-23.7.2         | 1.3 MB    | ######     |  60%
#
#
#
#
#
#
# jupyter_server-1.23. | 459 KB    | ########## | 100%
#
# conda-23.7.2         | 1.3 MB    | ######5    |  65%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | #5         |  16%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | #6         |  17%
#
# conda-23.7.2         | 1.3 MB    | #######2   |  72%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | #8         |  18%
#
# conda-23.7.2         | 1.3 MB    | ########   |  80%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | #9         |  20%
#
# conda-23.7.2         | 1.3 MB    | ########6  |  86%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ##         |  21%
#
# conda-23.7.2         | 1.3 MB    | #########2 |  92%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ##2        |  22%
#
# conda-23.7.2         | 1.3 MB    | #########8 |  98%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ##3        |  23%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ##6        |  27%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ##8        |  29%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ###        |  31%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ###3       |  34%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ###6       |  37%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ###8       |  39%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ####1      |  41%
#
# conda-23.7.2         | 1.3 MB    | ########## | 100%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ####3      |  44%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ####8      |  48%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | #####1     |  52%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | #####4     |  54%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | #####7     |  57%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ######1    |  62%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ######4    |  64%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ######7    |  67%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | #######    |  71%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | #######3   |  73%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | #######6   |  76%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ########3  |  84%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ########7  |  88%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | #########1 |  92%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | #########5 |  95%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | #########9 |  99%
#
#
#
# openssl-1.1.1v       | 5.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... failed
# EnvironmentNotWritableError: The current user does not have write permissions to the target environment.
#   environment location: C:\ProgramData\anaconda3

# %%
pd.read_excel('Excel_Sample.xlsx')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df.to_excel('Excel_Sample2.xlsx')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
#    1201 validate_header_arg(header)
#    1203 io = stringify_path(io)
# -> 1205 return _parse(
#    1206     flavor=flavor,
#    1207     io=io,
#    1208     match=match,
#    1209     header=header,
#    1210     index_col=index_col,
#    1211     skiprows=skiprows,
#    1212     parse_dates=parse_dates,
#    1213     thousands=thousands,
#    1214     attrs=attrs,
#    1215     encoding=encoding,
#    1216     decimal=decimal,
#    1217     converters=converters,
#    1218     na_values=na_values,
#    1219     keep_default_na=keep_default_na,
#    1220     displayed_only=displayed_only,
#    1221     extract_links=extract_links,
#    1222 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\html.py:982, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, **kwargs)
#     980 retained = None
#     981 for flav in flavor:
# --> 982     parser = _parser_dispatch(flav)
#     983     p = parser(io, compiled_match, attrs, encoding, displayed_only, extract_links)
#     985     try:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\html.py:931, in _parser_dispatch(flavor)
#     929 if flavor in ("bs4", "html5lib"):
#     930     if not _HAS_HTML5LIB:
# --> 931         raise ImportError("html5lib not found, please install it")
#     932     if not _HAS_BS4:
#     933         raise ImportError("BeautifulSoup4 (bs4) not found, please install it")
#
# ImportError: html5lib not found, please install it

# %%
conda install lxml

# %%
conda install html5lib

# %%
conda install BeautifulSoup4

# %%
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df[0]
#
# NameError: name 'df' is not defined
